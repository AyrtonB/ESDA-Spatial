# %% [markdown]
# # Tutorial 1
#
# <br>
#
# ### Imports

# %%
import pandas as pd
import geopandas as gpd

# %%
gdf_cities = gpd.read_file('data/africa_cities/cities_Africa.shp')

gdf_cities.head()
# Out:
#    LATLONGID   LATITUDE  LONGITUDE URBORRUR    YEAR  ES90POP  ES95POP  \
# 0        1.0 -12.578333  13.407222        U  1970.0   176286   244329
# 1        2.0 -12.852500  15.560556        U  1970.0    38244    53006
# 2        3.0  -5.550000  12.200000        U  1970.0    90834   125895
# 3        4.0 -12.016667  17.483333        U  1970.0    24682    34209
# 4        5.0 -10.850000  14.366667        U  1970.0    29799    41301
#
#    ES00POP INSGRUSED CONTINENT  ...   SCHADMNM      ADMNM1  ADMNM2 TYPE  \
# 0   311843         N    Africa  ...   BENGUELA    Benguela    None    C
# 1    67653         N    Africa  ...     HUAMBO      Huambo    None    C
# 2   160683         N    Africa  ...    CABINDA     Cabinda    None    C
# 3    43662         N    Africa  ...        BIE         Bié    None    C
# 4    52714         N    Africa  ...  CUANZASUL  Cuanza Sul    None    C
#
#    SRCTYP                           COORDSRCE           DATSRC  \
# ...

# %%
gdf_cities.plot(color='k', markersize=1)
