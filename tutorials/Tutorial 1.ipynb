# %% [markdown]
# # Tutorial 1
#
# <br>
#
# ### Imports

# %%
import pandas as pd

import xarray as xr
import geopandas as gpd

# %% [markdown]
# <br>
#
# ### Reading in Data
#
# We'll begin by reading in vector data of which there are three types: Polygons, Points & Lines. Here we'll read in the Polygons for African countries.

# %%
gdf_countries = gpd.read_file('data/africa_countries/Africa_countries.shp')

gdf_countries.plot()

# %% [markdown]
# <br>
#
# Next we'll read in Lines for major rivers

# %%
# %%time

gdf_rivers = gpd.read_file('data/rivers_Africa.gpkg')

gdf_rivers.plot(linewidth=0.5, alpha=0.5)
# Out:
# Wall time: 14.2 s

# %%
da_solar = xr.open_rasterio('data/solar/solar.tif')

da_solar.plot()
